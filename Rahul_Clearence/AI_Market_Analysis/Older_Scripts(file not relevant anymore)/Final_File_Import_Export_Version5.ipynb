# %%
import numpy as np 
import pandas as pd
import re 
import os

# %% [markdown]
# ## Loading all the files
# ### 2019 - 2021

# %%
df1 = pd.read_excel(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\2019-2021\Data19-21.xlsx")

# %%
df1.rename(columns = {'ORIGIN/DESTINATION COUNTRY':'Country'},inplace = True)

# %%
df1.isnull().sum()
# Out:
# Type                        0
# Date                        0
# IMPORTER/EXPORTER NAME      0
# Country                     0
# PRODUCT DESCRIPTION         0
# QTY                         0
# UNIT                        0
# UNIT PRICE (USD)            0
# Total_VALUE_USD             0
# INVOICE CURRENCY            1
# SUPPLIER/BUYER NAME       627
# Molecule Name              88
# Product Name                0
# dtype: int64

# %%
df1 = df1.dropna()

# %%
df1.isnull().sum()
# Out:
# Type                      0
# Date                      0
# IMPORTER/EXPORTER NAME    0
# Country                   0
# PRODUCT DESCRIPTION       0
# QTY                       0
# UNIT                      0
# UNIT PRICE (USD)          0
# Total_VALUE_USD           0
# INVOICE CURRENCY          0
# SUPPLIER/BUYER NAME       0
# Molecule Name             0
# Product Name              0
# dtype: int64

# %% [markdown]
# ------------------------- Treating the past data in the current script -----------------------------

# %%
## Reading the list of products to be used for search and store operation( This has been made using the file provided by Manish Upreti where the product names were extracted manually )
df = pd.read_csv(r"C:\Users\S1130866\Desktop\Product_Automate\product.csv")
products = [i for i in set(df.Products.str.lower().tolist()) if not isinstance(i, (int, float)) and i != '0']

# %%
    map_24d = { v: '2 4 d' for v in ['2 4-d', '24 d', '2,4-d', '2 4 d', '2 4- d', '2 4 -d', '2 4d',
       '2, 4 d', '2, 4-d', '2,4 - d', '2,4 d', '2,4- d', '2,4d', '2-4-d',
       '24d', '2-4 d', '24- d', '2-4- d', '2-4d', '24-d', '2, 4- d',
       '2, 4d', '2- 4-d']}
    
    
    def find_prod(x):
   
        #a = ('azoxystrobin')
        if re.search('R&D|RESEARCH|FREE SAMPLE|TESTING|SAMPLE|research|r&d|free|sample|lab|LAB|LAB USE|lab use|(lab use)|(Lab Use)|(LAB USE)|(Lab Use)',x) :
             return ""
        temp_products = list(set([i for i in products if i in re.split(' |\(|\)|\+|\\|/|\*|-|\s|\d|_|\.|,|\?|\^|\$|\[|\]|\{|\}',x.lower())]))
        if re.search('[2][-,\s]*[4][-\s]*[d]',x) :
             temp_products += [map_24d[re.search('[2][-,\s]*[4][-\s]*[d]',x)[0]]]
             #if re.search('AZOXY.{,50}|azoxy.{,50}',x):
              #temp_products += a
        if re.search('POTASH|potash|NPS|nps|PHOSPHATE|phosphate|SULFATE|sulfate|SULPHATE|sulphate',x):
             if len(temp_products)<1:
                    temp_products += 'fertilizer'
        if len(temp_products)>1 :
            temp_products = [i for i in temp_products if i!='pesticide']
            temp_products = [i for i in temp_products if i!='pesticides']
            temp_products = [i for i in temp_products if i!='rynaxypyr']
        return temp_products
        # Creating a function for the same
        
    def suf(x):
        temp_suffix = [] 
        if re.search('tech.{,50}|TECH.{,50}',x):
            temp_suffix = "TECH"
        elif re.search('IPA SALT|ipa salt',x):
            temp_suffix = "IPA SALT"
        elif re.search('62% IPA SALT|62% ipa salt',x):
            temp_suffix = "62% IPA SALT"
        elif re.search('41% SL|41% sl',x):
            temp_suffix = '41% SL'
        elif re.search('ALION PLUS.{50}|alion plus.{50}',x):
            temp_suffix = "ALION PLUS"
        else :
            temp_suffix = "Others"
        return temp_suffix

# %% [markdown]
# --------------------------------------------- Running the data on file for Jan and Feb ---------------

# %%
## 2022 - All months imp 
df2_imp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\Jan to July\38_Imp_TY2_Jan_to_Jul-22.csv",encoding = 'unicode_escape')
df2_exp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\Jan to July\38_Exp_TY2_Jan_to_Jul-22.csv",encoding = 'unicode_escape')
df3_imp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\August\38_Imp_TY2_Aug-22.csv",encoding = 'unicode_escape')
df3_exp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\August\38_Exp_TY2_Aug-22.csv",encoding = 'unicode_escape')
df4_imp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\September\38_Imp_TY2_Sep-22.csv",encoding = 'unicode_escape')
df4_exp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\September\38_Exp_TY2_Sep-22.csv",encoding = 'unicode_escape')
df5_imp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\October\38_Imp_TY2_Oct-22.csv",encoding = 'unicode_escape')
df5_exp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\October\38_Exp_TY2_Oct-22.csv",encoding = 'unicode_escape')
df6_imp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\November\38_Imp_TY2_Nov-22.csv",encoding = 'unicode_escape')
df6_exp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\November\38_Exp_TY2_Nov-22.csv",encoding = 'unicode_escape')
df7_imp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\December\38_Imp_TY2_Dec-22.csv",encoding = 'unicode_escape')
df7_exp = pd.read_csv(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Updated File\December\38_Exp_TY2_Dec-22.csv",encoding = 'unicode_escape')
df8_imp = pd.read_excel(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\File to be worked on\January 2023\Import\38_Imp_TY2_Jan-23.xlsx")
df8_exp = pd.read_excel(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\File to be worked on\January 2023\Export\38_Exp_TY2_Jan-23.xlsx")
df9_imp = pd.read_excel(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\File to be worked on\February 2023\Import\38_Imp_TY2_Feb-23.xlsx")
df9_exp = pd.read_excel(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\File to be worked on\February 2023\Export\38_Exp_TY2_Feb-23.xlsx")

# %% [markdown]
# -------------------------------------------------------------------
#
# Working on the data for the Jan and Feb
#
# -------------------------------------------------------------------

# %%
    ##Mapping the Product Description column as string as sometimes it may not be read as a string
    df8_imp['Goods Description'] = df8_imp['Goods Description'].map(str)
    
    print("Working on Product Mapping")
    temp = df8_imp['Goods Description'].apply(lambda x: find_prod(x))
    # temp = temp.apply(lambda x:pesticide_check(x))

    temp_processed = temp.apply(lambda x: ", ".join(x) if len(x)>=1 else "")
    
    print("Product Mapping done , working on other conditions")

    ## Checking for the condition where UNit is GMS and quantity is one is not detected and anything with 0 quantity is also not detected
    df8_imp.loc[np.logical_and(df8_imp['Unit'].gt('GMS'), np.less_equal(df8_imp['Quantity'], 1)), 'Product'] = ''
    df8_imp.loc[df8_imp["Quantity"]==0, "Product"] = ""
    
    ## Replacing the values that are returned as otherwise to the way we want it(The requirement is explained in the req doc)
    temp_processed.replace('a, z, o, x, y, s, t, r, o, b, i, n','azoxystrobin',inplace = True)
    temp_processed.replace('f, e, r, t, i, l, i, z, e, r','fertilizer',inplace = True)
    temp_processed.replace('mancozebe','mancozeb',inplace = True)
    temp_processed.replace('amoniusaltglyphosate71','glyphosate',inplace = True)
    temp_processed.replace('AMONIUSALTGLYPHOSATE7171','glyphosate',inplace = True)
    temp_processed.replace('rynaxypyr','chlorantraniliprole',inplace = True)
    temp_processed.replace('glyphosatee','glyphosate',inplace = True)
    temp_processed.replace('','Others',inplace = True)
    
    df8_imp['Product'] = temp_processed
    ## Filling up the blank values with 'Others'
    df8_imp['Product'] = df8_imp['Product'].fillna('Others')
    
    print("Product Mapping done , working on Suffix creation")
    

    
    
    df8_imp['suffix'] =  df8_imp['Goods Description'].apply(lambda x: suf(x))
    print("Suffix Creation done")
# Out:
# Working on Product Mapping
# Product Mapping done , working on other conditions
# Product Mapping done , working on Suffix creation
# Suffix Creation done

# %%
    ##Mapping the Product Description column as string as sometimes it may not be read as a string
    df8_exp['Goods Description'] = df8_exp['Goods Description'].map(str)
    
    print("Working on Product Mapping")
    temp = df8_exp['Goods Description'].apply(lambda x: find_prod(x))
    # temp = temp.apply(lambda x:pesticide_check(x))

    temp_processed = temp.apply(lambda x: ", ".join(x) if len(x)>=1 else "")
    
    print("Product Mapping done , working on other conditions")

    ## Checking for the condition where UNit is GMS and quantity is one is not detected and anything with 0 quantity is also not detected
    df8_exp.loc[np.logical_and(df8_exp['Unit'].gt('GMS'), np.less_equal(df8_exp['Quantity'], 1)), 'Product'] = ''
    df8_exp.loc[df8_exp["Quantity"]==0, "Product"] = ""
    
    ## Replacing the values that are returned as otherwise to the way we want it(The requirement is explained in the req doc)
    temp_processed.replace('a, z, o, x, y, s, t, r, o, b, i, n','azoxystrobin',inplace = True)
    temp_processed.replace('f, e, r, t, i, l, i, z, e, r','fertilizer',inplace = True)
    temp_processed.replace('mancozebe','mancozeb',inplace = True)
    temp_processed.replace('amoniusaltglyphosate71','glyphosate',inplace = True)
    temp_processed.replace('AMONIUSALTGLYPHOSATE7171','glyphosate',inplace = True)
    temp_processed.replace('rynaxypyr','chlorantraniliprole',inplace = True)
    temp_processed.replace('glyphosatee','glyphosate',inplace = True)
    temp_processed.replace('','Others',inplace = True)
    
    df8_exp['Product'] = temp_processed
    ## Filling up the blank values with 'Others'
    df8_exp['Product'] = df8_exp['Product'].fillna('Others')
    
    print("Product Mapping done , working on Suffix creation")
    
  
    
    df8_exp['suffix'] =  df8_exp['Goods Description'].apply(lambda x: suf(x))
    print("Suffix Creation done")
# Out:
# Working on Product Mapping
# Product Mapping done , working on other conditions
# Product Mapping done , working on Suffix creation
# Suffix Creation done

# %%
    df9_imp['Goods Description'] = df9_imp['Goods Description'].map(str)
    
    print("Working on Product Mapping")
    temp = df9_imp['Goods Description'].apply(lambda x: find_prod(x))
    # temp = temp.apply(lambda x:pesticide_check(x))

    temp_processed = temp.apply(lambda x: ", ".join(x) if len(x)>=1 else "")
    
    print("Product Mapping done , working on other conditions")

    ## Checking for the condition where UNit is GMS and quantity is one is not detected and anything with 0 quantity is also not detected
    df9_imp.loc[np.logical_and(df9_imp['Unit'].gt('GMS'), np.less_equal(df9_imp['Quantity'], 1)), 'Product'] = ''
    df9_imp.loc[df9_imp["Quantity"]==0, "Product"] = ""
    
    ## Replacing the values that are returned as otherwise to the way we want it(The requirement is explained in the req doc)
    temp_processed.replace('a, z, o, x, y, s, t, r, o, b, i, n','azoxystrobin',inplace = True)
    temp_processed.replace('f, e, r, t, i, l, i, z, e, r','fertilizer',inplace = True)
    temp_processed.replace('mancozebe','mancozeb',inplace = True)
    temp_processed.replace('amoniusaltglyphosate71','glyphosate',inplace = True)
    temp_processed.replace('AMONIUSALTGLYPHOSATE7171','glyphosate',inplace = True)
    temp_processed.replace('rynaxypyr','chlorantraniliprole',inplace = True)
    temp_processed.replace('glyphosatee','glyphosate',inplace = True)
    temp_processed.replace('','Others',inplace = True)
    
    df9_imp['Product'] = temp_processed
    ## Filling up the blank values with 'Others'
    df9_imp['Product'] = df9_imp['Product'].fillna('Others')
    
    print("Product Mapping done , working on Suffix creation")
    
    #### CREATING THE SUFFIX COLUMN

    
    df9_imp['suffix'] =  df9_imp['Goods Description'].apply(lambda x: suf(x))
    print("Suffix Creation done")
# Out:
# Working on Product Mapping
# Product Mapping done , working on other conditions
# Product Mapping done , working on Suffix creation
# Suffix Creation done

# %%
    df9_exp['Goods Description'] = df9_exp['Goods Description'].map(str)
    
    print("Working on Product Mapping")
    temp = df9_exp['Goods Description'].apply(lambda x: find_prod(x))
    # temp = temp.apply(lambda x:pesticide_check(x))

    temp_processed = temp.apply(lambda x: ", ".join(x) if len(x)>=1 else "")
    
    print("Product Mapping done , working on other conditions")

    ## Checking for the condition where UNit is GMS and quantity is one is not detected and anything with 0 quantity is also not detected
    df9_exp.loc[np.logical_and(df9_exp['Unit'].gt('GMS'), np.less_equal(df9_exp['Quantity'], 1)), 'Product'] = ''
    df9_exp.loc[df9_exp["Quantity"]==0, "Product"] = ""
    
    ## Replacing the values that are returned as otherwise to the way we want it(The requirement is explained in the req doc)
    temp_processed.replace('a, z, o, x, y, s, t, r, o, b, i, n','azoxystrobin',inplace = True)
    temp_processed.replace('f, e, r, t, i, l, i, z, e, r','fertilizer',inplace = True)
    temp_processed.replace('mancozebe','mancozeb',inplace = True)
    temp_processed.replace('amoniusaltglyphosate71','glyphosate',inplace = True)
    temp_processed.replace('AMONIUSALTGLYPHOSATE7171','glyphosate',inplace = True)
    temp_processed.replace('rynaxypyr','chlorantraniliprole',inplace = True)
    temp_processed.replace('glyphosatee','glyphosate',inplace = True)
    temp_processed.replace('','Others',inplace = True)
    
    df9_exp['Product'] = temp_processed
    ## Filling up the blank values with 'Others'
    df9_exp['Product'] = df9_exp['Product'].fillna('Others')
    
    print("Product Mapping done , working on Suffix creation")
    
    #### CREATING THE SUFFIX COLUMN

    
    df9_exp['suffix'] =  df9_exp['Goods Description'].apply(lambda x: suf(x))
    print("Suffix Creation done")
# Out:
# Working on Product Mapping
# Product Mapping done , working on other conditions
# Product Mapping done , working on Suffix creation
# Suffix Creation done

# %%
pwd
# Out:
# 'C:\\Users\\S1130866\\Desktop\\Product_Automate'

# %%
df8_imp.to_csv("38_Imp_TY2_Jan-23.csv")
df8_exp.to_csv("38_Exp_TY2_Jan-23.csv")
df9_imp.to_csv("38_Imp_TY2_Feb-23.csv")
df9_exp.to_csv("38_Exp_TY2_Feb-23.csv")

# %%
df22_imp = pd.concat([df2_imp,df3_imp,df4_imp,df5_imp,df6_imp,df7_imp],axis = 0)

# %%
df22_imp.drop("Unnamed: 0",axis = 1 , inplace = True)

# %% [markdown]
# ------------------------- Treating the past data in the current script -----------------------------

# %%
df22_imp = pd.concat([df22_imp,df8_imp,df9_imp],axis = 0)

# %%
df22_imp.shape
# Out:
# (773399, 27)

# %%
df22_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 773399 entries, 0 to 51517
# Data columns (total 27 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Port Code          773399 non-null  object
#  1   Indian Port        773399 non-null  object
#  2   Declaration No     773399 non-null  object
#  3   Date               773399 non-null  object
#  4   Importer Name      773399 non-null  object
#  5   Address            772469 non-null  object
#  6   City               766401 non-null  object
#  7   CHA No             0 non-null       float64
#  8   CHA Name           264242 non-null  object
#  9   Country Origin     773398 non-null  object
#  10  HS Code            773399 non-null  int64
#  11  Goods Description  773398 non-null  object
#  12  Quantity           773399 non-null  float64
#  13  Unit               773399 non-null  object
#  14  Unit Price Usd     773399 non-null  float64
# ...

# %%
## Concatinating the export data

# %%
df22_exp = pd.concat([df2_exp,df3_exp,df4_exp,df5_exp,df6_exp,df7_exp],axis = 0)

# %%
df22_exp.columns
# Out:
# Index(['Unnamed: 0', 'Declaration No', 'HS Four Digit', 'Date', 'HS Code',
#        'Goods Description', 'Quantity', 'Unit', 'Currency', 'Unit Value Usd',
#        'Fob Usd', 'Destination Port', 'Country', 'Indian Port',
#        'Exporter Name', 'Address', 'City', 'Consinee Name', 'Consinee Address',
#        'Port Code', 'IEC Phone', 'IEC Email', 'IEC Contact', 'Product',
#        'suffix'],
#       dtype='object')

# %%
df22_exp.drop('Unnamed: 0',axis =1 , inplace = True)

# %%
df22_exp = pd.concat([df22_exp,df8_exp,df9_exp],axis = 0)

# %%
df22_exp.shape
# Out:
# (360117, 24)

# %%
## Bringing the Export file in the required format : 

### Block for altering the entire data into the required format

temp2 = df22_exp.drop(['Declaration No', 'HS Four Digit', 'HS Code','Destination Port','Indian Port','Address', 'City','Consinee Address','Port Code', 'IEC Phone', 'IEC Email', 'IEC Contact'],axis = 1)
temp2['Product Name'] = temp2['Product'] + " " + temp2['suffix']
temp2 = temp2.drop('suffix',axis = 1)
temp2['Type'] = 'Export'
temp2.rename(columns = {'Exporter Name':'IMPORTER/EXPORTER NAME','Country Origin':'Country','Goods Description':'PRODUCT DESCRIPTION','Quantity':'QTY','Unit':'UNIT','Unit Value Usd':'UNIT PRICE (USD)','Fob Usd':'Total_VALUE_USD','Currency':'INVOICE CURRENCY','Consinee Name':'SUPPLIER/BUYER NAME','Product':'Molecule Name'},inplace = True)

temp2 = temp2.loc[:,["Type","Date","IMPORTER/EXPORTER NAME","Country","PRODUCT DESCRIPTION","QTY","UNIT","UNIT PRICE (USD)","Total_VALUE_USD","INVOICE CURRENCY","SUPPLIER/BUYER NAME","Molecule Name","Product Name"]]
temp2['Product Name'].replace('Others Others','Others',inplace = True)

# %%
temp2.shape
# Out:
# (360117, 13)

# %%
## Bringing the Import file in the required format : 

### Block for altering the entire data into the required format


temp = df22_imp.drop(['Port Code', 'Indian Port', 'Declaration No','Address', 'City', 'CHA No', 'CHA Name','HS Code','Total_Duty_Usd', 'Loading Port','Supplier Address', 'BE Type', 'IEC Phone','IEC Email', 'IEC Contact'],axis = 1)
temp['Product Name'] = temp['Product'] + " " + temp['suffix']
temp = temp.drop('suffix',axis = 1)
temp['Type'] = 'Import'
temp.rename(columns = {'Importer Name':'IMPORTER/EXPORTER NAME','Country Origin':'Country','Goods Description':'PRODUCT DESCRIPTION','Quantity':'QTY','Unit':'UNIT','Unit Price Usd':'UNIT PRICE (USD)','Total Value Usd':'Total_VALUE_USD','Inv Currency':'INVOICE CURRENCY','Supplier Name':'SUPPLIER/BUYER NAME','Product':'Molecule Name'},inplace = True)



temp = temp.loc[:,["Type","Date","IMPORTER/EXPORTER NAME","Country","PRODUCT DESCRIPTION","QTY","UNIT","UNIT PRICE (USD)","Total_VALUE_USD","INVOICE CURRENCY","SUPPLIER/BUYER NAME","Molecule Name","Product Name"]]
temp['Product Name'].replace('Others Others','Others',inplace = True)

# %%
temp.shape
# Out:
# (773399, 13)

# %%
list1 = temp.columns

# %%
list2 = temp2.columns

# %%
list1 == list2
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
list3 = df1.columns

# %%
list1 == list3
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
data = pd.concat([temp,temp2,df1])

# %%
data.shape
# Out:
# (1157398, 13)

# %%
data.isnull().sum()
# Out:
# Type                         0
# Date                         0
# IMPORTER/EXPORTER NAME       2
# Country                     10
# PRODUCT DESCRIPTION          1
# QTY                          0
# UNIT                         0
# UNIT PRICE (USD)             0
# Total_VALUE_USD              0
# INVOICE CURRENCY             0
# SUPPLIER/BUYER NAME       5138
# Molecule Name                0
# Product Name                 0
# dtype: int64

# %%
data2 = data.dropna()

# %%
data2.isnull().sum()
# Out:
# Type                      0
# Date                      0
# IMPORTER/EXPORTER NAME    0
# Country                   0
# PRODUCT DESCRIPTION       0
# QTY                       0
# UNIT                      0
# UNIT PRICE (USD)          0
# Total_VALUE_USD           0
# INVOICE CURRENCY          0
# SUPPLIER/BUYER NAME       0
# Molecule Name             0
# Product Name              0
# dtype: int64

# %%
data2.shape
# Out:
# (1152247, 13)

# %%
data2['Date'] = pd.to_datetime(data2['Date'])
# Out:
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/668368783.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['Date'] = pd.to_datetime(data2['Date'])

# %%
data2.head()
# Out:
#      Type       Date                   IMPORTER/EXPORTER NAME        Country  \
# 0  Import 2022-01-01  CHROMACHEMIE LABORATORY PRIVATE LIMITED  UNITED STATES
# 1  Import 2022-01-01  CHROMACHEMIE LABORATORY PRIVATE LIMITED  UNITED STATES
# 2  Import 2022-01-01  CHROMACHEMIE LABORATORY PRIVATE LIMITED  UNITED STATES
# 3  Import 2022-01-01  CHROMACHEMIE LABORATORY PRIVATE LIMITED  UNITED STATES
# 4  Import 2022-01-01  CHROMACHEMIE LABORATORY PRIVATE LIMITED  UNITED STATES
#
#                                  PRODUCT DESCRIPTION   QTY  UNIT  \
# 0  USP-1396342_METFORMIN RELATED COMPOUND C -(25 ...   4.0  NOS
# 1  USP-1432005_METHYLPARABEN -(125 MG)-(PHARMACEU...  19.0  NOS
# 2  USP-1441298_METOPROLOL SUCCINATE -(200 MG)-(PH...   4.0  NOS
# 3  USP-1446815_MONTELUKAST DICYCLOHEXYLAMINE -(15...   6.0  NOS
# 4  USP-1448617_MOXIFLOXACIN RELATED COMPOUND A -(...   3.0  NOS
#
#    UNIT PRICE (USD)  Total_VALUE_USD INVOICE CURRENCY  \
# 0        734.136941      2936.547764             USD
# ...

# %%
data3 = data2[data2['Molecule Name'] != 'Others']

# %%
data3.shape
# Out:
# (172786, 13)

# %%
data3.head()
# Out:
#       Type       Date                   IMPORTER/EXPORTER NAME        Country  \
# 5   Import 2022-01-01  CHROMACHEMIE LABORATORY PRIVATE LIMITED  UNITED STATES
# 6   Import 2022-01-01  CHROMACHEMIE LABORATORY PRIVATE LIMITED  UNITED STATES
# 32  Import 2022-01-01     WELDON BIOTECH INDIA PRIVATE LIMITED         CANADA
# 33  Import 2022-01-01     WELDON BIOTECH INDIA PRIVATE LIMITED         CANADA
# 34  Import 2022-01-01     WELDON BIOTECH INDIA PRIVATE LIMITED         CANADA
#
#                                   PRODUCT DESCRIPTION  QTY  UNIT  \
# 5   USP-1448989_MYCOPHENOLATE SODIUM -(200 MG) -(P...  2.0  NOS
# 6   USP-1460000_NEOSTIGMINE METHYLSULFATE -(200 MG...  1.0  NOS
# 32  CAN-IGF-4140 INSULIN LIKE GROWTH FACTOR BINDIN...  1.0  PCS
# 33  CAN-TE-250 TESTOSTERONE TOTAL ELISA TEST KIT (...  2.0  PCS
# 34  CAN-CRP-4360 C-REACTIVE PROTEIN (HS-CRP) ELISA...  5.0  PCS
#
#     UNIT PRICE (USD)  Total_VALUE_USD INVOICE CURRENCY  \
# ...

# %%
data3.to_csv("data3.csv")

# %%
data3.columns
# Out:
# Index(['Type', 'Date', 'IMPORTER/EXPORTER NAME', 'Country',
#        'PRODUCT DESCRIPTION', 'QTY', 'UNIT', 'UNIT PRICE (USD)',
#        'Total_VALUE_USD', 'INVOICE CURRENCY', 'SUPPLIER/BUYER NAME',
#        'Molecule Name', 'Product Name'],
#       dtype='object')

# %%
data3.shape
# Out:
# (172786, 13)

# %%
df_final_compiled2 = data3

# %%
data3.head()
# Out:
#       Type       Date                   IMPORTER/EXPORTER NAME        Country  \
# 5   Import 2022-01-01  CHROMACHEMIE LABORATORY PRIVATE LIMITED  UNITED STATES
# 6   Import 2022-01-01  CHROMACHEMIE LABORATORY PRIVATE LIMITED  UNITED STATES
# 32  Import 2022-01-01     WELDON BIOTECH INDIA PRIVATE LIMITED         CANADA
# 33  Import 2022-01-01     WELDON BIOTECH INDIA PRIVATE LIMITED         CANADA
# 34  Import 2022-01-01     WELDON BIOTECH INDIA PRIVATE LIMITED         CANADA
#
#                                   PRODUCT DESCRIPTION  QTY  UNIT  \
# 5   USP-1448989_MYCOPHENOLATE SODIUM -(200 MG) -(P...  2.0  NOS
# 6   USP-1460000_NEOSTIGMINE METHYLSULFATE -(200 MG...  1.0  NOS
# 32  CAN-IGF-4140 INSULIN LIKE GROWTH FACTOR BINDIN...  1.0  PCS
# 33  CAN-TE-250 TESTOSTERONE TOTAL ELISA TEST KIT (...  2.0  PCS
# 34  CAN-CRP-4360 C-REACTIVE PROTEIN (HS-CRP) ELISA...  5.0  PCS
#
#     UNIT PRICE (USD)  Total_VALUE_USD INVOICE CURRENCY  \
# ...

# %%
#### -------------------------------  WORKING ON THE COUNTRY, COMPANY , QTY and Molecule Name Columns  -------------------------



#### Working on the compnay column i,e IMPORTER/EXPORTER NAME

company = pd.read_excel(r'C:\Users\S1130866\Desktop\Product_Automate\Country and company.xlsx')
country = pd.read_excel(r'C:\Users\S1130866\Desktop\Product_Automate\Country and company.xlsx',sheet_name = "Country") 

unique = company.drop_duplicates()
unique_mismatches = unique[unique['Company'].str.lower() != unique['New'].str.lower()]
company_key_value = dict(zip(unique_mismatches['Company'].str.lower(),unique_mismatches['New'].str.lower()))
df_final_compiled2['IMPORTER/EXPORTER NAME'] = df_final_compiled2['IMPORTER/EXPORTER NAME'].str.lower().replace(company_key_value)



### Working on the country column



unique2 = country.drop_duplicates()
unique_mismatches2 = unique2[unique2['Country'].str.lower() != unique2['New'].str.lower()]
country_key_value = dict(zip(unique_mismatches2['Country'].str.lower(),unique_mismatches2['New'].str.lower()))
df_final_compiled2['Country'] = df_final_compiled2['Country'].str.lower().replace(country_key_value)
# Out:
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/130939515.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_compiled2['IMPORTER/EXPORTER NAME'] = df_final_compiled2['IMPORTER/EXPORTER NAME'].str.lower().replace(company_key_value)
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/130939515.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_compiled2['Country'] = df_final_compiled2['Country'].str.lower().replace(country_key_value)

# %%
### -------------------------------  UNIT COLUMN -------------------------------------------

df_final_compiled3 = df_final_compiled2

# df_final_compiled3['UNIT'] =df_final_compiled3['UNIT'].str.rstrip().replace(unit_dict)



df_final_compiled3['UNIT'] = df_final_compiled3['UNIT'].apply(lambda x: x.strip())




#1l = 1kg
# Out:
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/2446020500.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_compiled3['UNIT'] = df_final_compiled3['UNIT'].apply(lambda x: x.strip())

# %%
df_final_compiled3.head()
# Out:
#       Type       Date                   IMPORTER/EXPORTER NAME        Country  \
# 5   Import 2022-01-01  chromachemie laboratory private limited  united states
# 6   Import 2022-01-01  chromachemie laboratory private limited  united states
# 32  Import 2022-01-01     weldon biotech india private limited         canada
# 33  Import 2022-01-01     weldon biotech india private limited         canada
# 34  Import 2022-01-01     weldon biotech india private limited         canada
#
#                                   PRODUCT DESCRIPTION  QTY UNIT  \
# 5   USP-1448989_MYCOPHENOLATE SODIUM -(200 MG) -(P...  2.0  NOS
# 6   USP-1460000_NEOSTIGMINE METHYLSULFATE -(200 MG...  1.0  NOS
# 32  CAN-IGF-4140 INSULIN LIKE GROWTH FACTOR BINDIN...  1.0  PCS
# 33  CAN-TE-250 TESTOSTERONE TOTAL ELISA TEST KIT (...  2.0  PCS
# 34  CAN-CRP-4360 C-REACTIVE PROTEIN (HS-CRP) ELISA...  5.0  PCS
#
#     UNIT PRICE (USD)  Total_VALUE_USD INVOICE CURRENCY  \
# ...

# %%
df_final_compiled3['QTY_MT'] = df_final_compiled3.apply(lambda x: x['QTY'] * 0.001 if x['UNIT']== 'KGS' else x['QTY'], axis=1)
df_final_compiled3['QTY_MT'] = df_final_compiled3.apply(lambda x: x['QTY'] * 0.001 if x['UNIT']== 'LTR' else x['QTY'], axis=1)
df_final_compiled3['QTY_MT'] = df_final_compiled3.apply(lambda x: x['QTY'] * 0.001 if x['UNIT']== 'LT/KG' else x['QTY'], axis=1)
df_final_compiled3['QTY_MT'] = df_final_compiled3.apply(lambda x: x['QTY'] * 1 if x['UNIT']== 'MTS' else x['QTY'], axis=1)
df_final_compiled3['QTY_MT'] = df_final_compiled3.apply(lambda x: x['QTY'] * 1 if x['UNIT']== 'MLT' else x['QTY'], axis=1)
df_final_compiled3['QTY_MT'] = df_final_compiled3.apply(lambda x: x['QTY'] * 0.000001 if x['UNIT']== 'MGS' else x['QTY'], axis=1)
df_final_compiled3['QTY_MT'] = df_final_compiled3.apply(lambda x: x['QTY'] * 0.000001 if x['UNIT']== 'GMS' else x['QTY'], axis=1)
df_final_compiled3['QTY_MT'] = df_final_compiled3.apply(lambda x: x['QTY'] * 0.000453592 if x['UNIT']== 'LBS' else x['QTY'], axis=1)














## Values to be converted into the required format 

"""

'KGS':'KG/LT',
'KGS':'KG/LT ,
'GMS':'GMs/ML' ,
'GMS':'GMs/ML' ,
'LT/KG':'KG/LT'
'LTR':'KG/LT',
'LTR':'KG/LT',
'MTS':'Metric Tons' ,
'MTS':'Metric Tons' ,
'MLT':'Metric LT '
'MGS':'GMs/ML' ,
'MGS':'GMs/ML'


"""



unit_dict_Other = {
'BAG':'Other',
'BTL':'Other', 
'CAN':'Other',
'CBM':'Other',
'CTM':'Other',
'DOZ':'Other',
'DRM':'Other',
'GRS':'Other',
'KGA':'Other',
'KIT':'Other',
'KLR':'Other',
'MTR':'Other',
'MTR':'Other',
'NOS':'Other',
'NOS':'Other',
'PAC':'Other',
'PCS':'Other',
'PCS':'Other',
'PRS':'Other',
'RLS':'Other',
'SET':'Other',
'SET':'Other',
'SQM':'Other',
'THD':'Other',
'TUB':'Other',
'UNT':'Other',
'UNT':'Other',
'VLS':'Other',
'VLS':'Other',
'TBS':'Other',
'BRL':'Other',
'KGS':'MT',
'GMS':'MT',
'LT/KG':'MT',
'LTR':'MT',
'MTS':'MT',
'MLT':'MT',
'MGS':'MT',
'LBS':'MT',
'MT':'MT',
'Other':'Other'
}
# Out:
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/1139661036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_compiled3['QTY_MT'] = df_final_compiled3.apply(lambda x: x['QTY'] * 0.001 if x['UNIT']== 'KGS' else x['QTY'], axis=1)
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/1139661036.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_compiled3['QTY_MT'] = df_final_compiled3.apply(lambda x: x['QTY'] * 0.001 if x['UNIT']== 'LTR' else x['QTY'], axis=1)
# ...

# %%
df_final_compiled3['UNIT_MT'] = df_final_compiled3['UNIT'].map(unit_dict_Other)
# Out:
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/527558684.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_compiled3['UNIT_MT'] = df_final_compiled3['UNIT'].map(unit_dict_Other)

# %%
df_final_compiled3.head()
# Out:
#       Type       Date                   IMPORTER/EXPORTER NAME        Country  \
# 5   Import 2022-01-01  chromachemie laboratory private limited  united states
# 6   Import 2022-01-01  chromachemie laboratory private limited  united states
# 32  Import 2022-01-01     weldon biotech india private limited         canada
# 33  Import 2022-01-01     weldon biotech india private limited         canada
# 34  Import 2022-01-01     weldon biotech india private limited         canada
#
#                                   PRODUCT DESCRIPTION  QTY UNIT  \
# 5   USP-1448989_MYCOPHENOLATE SODIUM -(200 MG) -(P...  2.0  NOS
# 6   USP-1460000_NEOSTIGMINE METHYLSULFATE -(200 MG...  1.0  NOS
# 32  CAN-IGF-4140 INSULIN LIKE GROWTH FACTOR BINDIN...  1.0  PCS
# 33  CAN-TE-250 TESTOSTERONE TOTAL ELISA TEST KIT (...  2.0  PCS
# 34  CAN-CRP-4360 C-REACTIVE PROTEIN (HS-CRP) ELISA...  5.0  PCS
#
#     UNIT PRICE (USD)  Total_VALUE_USD INVOICE CURRENCY  \
# ...

# %%
###  ----------- ORDER FOR AI's  --------------------

AI_Order = pd.read_excel(r"C:\Users\S1130866\Desktop\Product_Automate\Tech vs Other.xlsx")


AI_Mapping = dict(zip(AI_Order['Product Name 1'].str.lower(),AI_Order['Product Name 2'].str.lower()))

AI_Mapping

def AI_MAP(x) :
    a = 'Others'
    if x in AI_Mapping.keys():
        x.map(AI_Mapping)
    else  : 
        elements =  [i for i in x.split(', ')]
        if len(elements)>1:
            return str(a)
        else : 
            return x

df_final_compiled3['AI'] = df_final_compiled3['Product Name'].apply(lambda x : x.lower())

df_final_compiled3['AI'] = df_final_compiled3['AI'].map(AI_Mapping).fillna(df_final_compiled3['Product Name'])



df_final_compiled3['Country'] = df_final_compiled3['Country'].str.capitalize()
df_final_compiled3['IMPORTER/EXPORTER NAME'] = df_final_compiled3['IMPORTER/EXPORTER NAME'].str.capitalize()


    


df_final_compiled4 = df_final_compiled3.loc[df_final_compiled3['UNIT_MT'] == 'MT']
# Out:
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/1207776087.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_compiled3['AI'] = df_final_compiled3['Product Name'].apply(lambda x : x.lower())
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/1207776087.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_compiled3['AI'] = df_final_compiled3['AI'].map(AI_Mapping).fillna(df_final_compiled3['Product Name'])
# ...

# %%
df_final_compiled4.head()
# Out:
#        Type       Date        IMPORTER/EXPORTER NAME    Country  \
# 178  Import 2022-01-01             S s international  Indonesia
# 185  Import 2022-01-01  Dbl ventures private limited   Malaysia
# 186  Import 2022-01-01  Dbl ventures private limited   Malaysia
# 188  Import 2022-01-01               Merchem limited      China
# 436  Import 2022-01-01                         Bayer      Japan
#
#                                    PRODUCT DESCRIPTION      QTY UNIT  \
# 178  GUM ROSIN WW GRADE IN ZINC DRUMS (NOT FOR USE ...  19200.0  KGS
# 185  COATED CALCIUM CARBONATE PRI-2T (25KG/PRINTED ...    185.5  MTS
# 186  COATED CALCIUM CARBONATE PRI-2T (25KG/PRINTED ...    265.0  MTS
# 188                         INSOLUBLE SULPHUR HD OT-20  14000.0  KGS
# 436  FLUBENDIAMIDE (NIH-KM) TC 1X500KG FBC WW (CIB ...  10000.0  KGS
#
#      UNIT PRICE (USD)  Total_VALUE_USD INVOICE CURRENCY  \
# 178          1.735000     3.331200e+04             USD
# ...

# %%
df_final_compiled4.head()
# Out:
#        Type       Date        IMPORTER/EXPORTER NAME    Country  \
# 178  Import 2022-01-01             S s international  Indonesia
# 185  Import 2022-01-01  Dbl ventures private limited   Malaysia
# 186  Import 2022-01-01  Dbl ventures private limited   Malaysia
# 188  Import 2022-01-01               Merchem limited      China
# 436  Import 2022-01-01                         Bayer      Japan
#
#                                    PRODUCT DESCRIPTION      QTY UNIT  \
# 178  GUM ROSIN WW GRADE IN ZINC DRUMS (NOT FOR USE ...  19200.0  KGS
# 185  COATED CALCIUM CARBONATE PRI-2T (25KG/PRINTED ...    185.5  MTS
# 186  COATED CALCIUM CARBONATE PRI-2T (25KG/PRINTED ...    265.0  MTS
# 188                         INSOLUBLE SULPHUR HD OT-20  14000.0  KGS
# 436  FLUBENDIAMIDE (NIH-KM) TC 1X500KG FBC WW (CIB ...  10000.0  KGS
#
#      UNIT PRICE (USD)  Total_VALUE_USD INVOICE CURRENCY  \
# 178          1.735000     3.331200e+04             USD
# ...

# %%
df_final_compiled4.to_excel(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Compiled_File\Main.xlsx",sheet_name = 'Data',index = False)

# %%
df_final_compiled4['QTY_MT'] = df_final_compiled4.apply(lambda x: x['QTY_MT'] * 0.001 if x['UNIT']== 'KGS' else x['QTY_MT'], axis=1)
df_final_compiled4['QTY_MT'] = df_final_compiled4.apply(lambda x: x['QTY_MT'] * 0.001 if x['UNIT']== 'LTR' else x['QTY_MT'], axis=1)
df_final_compiled4['QTY_MT'] = df_final_compiled4.apply(lambda x: x['QTY_MT'] * 0.001 if x['UNIT']== 'LT/KG' else x['QTY_MT'], axis=1)
df_final_compiled4['QTY_MT'] = df_final_compiled4.apply(lambda x: x['QTY_MT'] * 1 if x['UNIT']== 'MTS' else x['QTY_MT'], axis=1)
df_final_compiled4['QTY_MT'] = df_final_compiled4.apply(lambda x: x['QTY_MT'] * 1 if x['UNIT']== 'MLT' else x['QTY_MT'], axis=1)
df_final_compiled4['QTY_MT'] = df_final_compiled4.apply(lambda x: x['QTY_MT'] * 0.000001 if x['UNIT']== 'MGS' else x['QTY_MT'], axis=1)
df_final_compiled4['QTY_MT'] = df_final_compiled4.apply(lambda x: x['QTY_MT'] * 0.000001 if x['UNIT']== 'GMS' else x['QTY_MT'], axis=1)
df_final_compiled4['QTY_MT'] = df_final_compiled4.apply(lambda x: x['QTY_MT'] * 0.000453592 if x['UNIT']== 'LBS' else x['QTY_MT'], axis=1)
# Out:
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/3991091783.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_compiled4['QTY_MT'] = df_final_compiled4.apply(lambda x: x['QTY_MT'] * 0.001 if x['UNIT']== 'KGS' else x['QTY_MT'], axis=1)
# C:\Users\S1130866\AppData\Local\Temp/ipykernel_10848/3991091783.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_final_compiled4.head()
# Out:
#        Type       Date        IMPORTER/EXPORTER NAME    Country  \
# 178  Import 2022-01-01             S s international  Indonesia
# 185  Import 2022-01-01  Dbl ventures private limited   Malaysia
# 186  Import 2022-01-01  Dbl ventures private limited   Malaysia
# 188  Import 2022-01-01               Merchem limited      China
# 436  Import 2022-01-01                         Bayer      Japan
#
#                                    PRODUCT DESCRIPTION      QTY UNIT  \
# 178  GUM ROSIN WW GRADE IN ZINC DRUMS (NOT FOR USE ...  19200.0  KGS
# 185  COATED CALCIUM CARBONATE PRI-2T (25KG/PRINTED ...    185.5  MTS
# 186  COATED CALCIUM CARBONATE PRI-2T (25KG/PRINTED ...    265.0  MTS
# 188                         INSOLUBLE SULPHUR HD OT-20  14000.0  KGS
# 436  FLUBENDIAMIDE (NIH-KM) TC 1X500KG FBC WW (CIB ...  10000.0  KGS
#
#      UNIT PRICE (USD)  Total_VALUE_USD INVOICE CURRENCY  \
# 178          1.735000     3.331200e+04             USD
# ...

# %%
df_final_compiled4.to_excel(r"C:\Users\S1130866\OneDrive - Syngenta\Documents\Shared\Product_Automate\Product_Automate\Import_Export\Compiled_File\Main.xlsx",sheet_name = 'Data',index = False)
